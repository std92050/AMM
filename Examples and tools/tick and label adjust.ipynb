# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
fig= plt.figure(figsize=(7,7))
ax = plt.subplot( projection = "3d")
x = np.arange(10)
y = 3*np.arange(10)+0.03

ax.bar3d(x,y,1,dx=0.5,dy=0.5 ,dz=0.1)



new_ticks_dict = { 5.3013 :'8=D' , 3.6 :'dick' , 8 : "dd"}
new_ticks = np.array(  list(  new_ticks_dict.keys()   ) )
x_ticks = np.append(ax.get_xticks() , new_ticks )
ax.set_xticks(x_ticks)

for lab in ax.get_xticklabels():
    lab_text = lab.get_text()
    print(lab.get_text())
    if lab_text in new_ticklabels :
        lab.set_fontsize(8)  # 调整字体大小
        lab.set_rotation(64)  # rotate
        lab.set_color('r')
#plt.tight_layout(pad=1)

# %%
a = ax.get_xticks()
b = ax.get_xticklabels()
b[0].set_text("fdf")
b
# Out:
# [Text(-2.0, -0.05748975552613349, 'fdf'),
#  Text(0.0, -0.06277000067271185, '0.0'),
#  Text(2.0, -0.06813881878634677, '2.0'),
#  Text(4.0, -0.0735984573553202, '4.0'),
#  Text(6.0, -0.07915124055484597, '6.0'),
#  Text(8.0, -0.08479957254602083, '8.0'),
#  Text(10.0, -0.09054594094655198, '10.0'),
#  Text(5.3013, -0.0772006410286451, '5.3'),
#  Text(3.6, -0.07249915357508854, '3.6'),
#  Text(8.0, -0.08479957254602083, '8.0')]
