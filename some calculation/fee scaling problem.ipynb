# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
delta = 1
r_0 = 0.667
def min_dist( array , r) :
    diff = abs(r - array) 
    mini = min(diff)
    return array[   np.where( diff == mini)[0][0] ]
def r(delta , r_0 , n):
    gamma = r_0
    value = np.array([])
    for k in range(1000):
        value = np.append( value , np.exp(-1*k*delta /np.sqrt(n)))
    return min_dist( value , r_0 )

# %%
value = np.array([])
value =np.append(value , np.array( [ i**2 for i in range(10)] ) )

# %%
diff = abs(40-value)
diff
# Out:
# array([40., 39., 36., 31., 24., 15.,  4.,  9., 24., 41.])

# %%
mini = min(diff)
value [np.where( diff == mini)[0][0] ]
# Out:
# 36.0

# %%
min_dist(value , 40)
# Out:
# 36.0

# %%
#gamma_array = np.array( [r(4 , 0.332 , n) for n in np.arange(1,10000)])
plt.ylim(0.3 , 0.34)
plt.plot(gamma_array  )

# %%
np.arange(,5)
# Out:
# array([0, 1, 2, 3, 4])
