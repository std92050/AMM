# %%
from numpy import sin ,cos ,pi ,linspace
import matplotlib.pyplot as plt

# %%
w_0=1.656
w_z=2.9*10**(-5)

N=432000
t = linspace(0, N,1000)

x, y = 0.5*cos(w_0*t)*cos(w_z*t), -0.5*cos(w_0*t)*sin(w_z*t)

fig, ax = plt.subplots()
ax.plot(x, y)
plt.show()
