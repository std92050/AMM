# %%
# %matplotlib inline
import matplotlib.pyplot as p
import math
import numpy as n
b=0.05
w0=0.06
D=[]
delta=[]
A=1
for i in n.arange(-0.5,0.5,0.01):
    D.append(A*pow(pow(pow(w0,2)+pow(i,2),2)+4*pow(i*b,2),-0.5))
#D vs w
#p.plot(n.arange(-0.5,0.5,0.01),D)
for i in n.arange(-1,-0.1,0.01):
    delta.append(math.atan(2*i*b/(pow(w0,2)-pow(i,2))))
#p.plot(n.arange(-1,-0.1,0.01),delta)
